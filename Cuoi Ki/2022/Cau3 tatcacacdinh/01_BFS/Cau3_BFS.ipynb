# %% [markdown]
# Câu 3: Cho cây `G = (V, E)` như hình vẽ. Trọng số trên đỉnh là heuristic `h(n)`, giá trị càng nhỏ thì càng gần trạng thái đích. Trọng số trên cạnh là chi phí đi qua cạnh. Cần tìm đường đi từ `S` đến một đỉnh có `h = 0`.

# %% [markdown]
# a)	Hãy viết đoạn code biểu diễn cây trên bằng cách khởi tạo tập đỉnh `V`, trọng số heuristic trên đỉnh `H` và tập cạnh có chi phí `E`.

# %% [markdown]
# Dán code:

# %%
V = ["S", "A", "B", "C", "D", "E", "F", "G", "H", "K", "M", "N", "I", "J", "L", "Z"]

H = {
    "S": 10,
    "A": 9,
    "B": 8,
    "C": 7,
    "D": 6,
    "E": 5,
    "F": 4,
    "G": 10,
    "H": 10,
    "K": 3,
    "M": 0,
    "N": 10,
    "I": 6,
    "J": 0,
    "L": 9,
    "Z": 8,
}

E = [
    ("S", "A", 5),
    ("S", "B", 6),
    ("S", "C", 5),
    ("A", "D", 6),
    ("A", "E", 7),
    ("D", "M", 5),
    ("D", "N", 8),
    ("E", "I", 8),
    ("B", "F", 3),
    ("B", "G", 4),
    ("F", "J", 4),
    ("F", "L", 4),
    ("C", "H", 6),
    ("C", "K", 4),
    ("K", "Z", 2),
]

class Graph:
    def __init__(self):
        self.adjacency = {}
        self.heuristic = {}

    def add_node(self, node, heuristic_value):
        if node not in self.adjacency:
            self.adjacency[node] = []
        self.heuristic[node] = heuristic_value

    def add_edge(self, u, v, cost):
        self.adjacency[u].append((v, cost))
        self.adjacency[v].append((u, cost))

    def sort_neighbors(self, vertex_order):
        for node in self.adjacency:
            self.adjacency[node].sort(key=lambda item: vertex_order[item[0]])


def build_graph(vertices, edges, heuristic_values):
    graph = Graph()

    for vertex in vertices:
        graph.add_node(vertex, heuristic_values[vertex])

    for u, v, cost in edges:
        graph.add_edge(u, v, cost)

    vertex_order = {vertex: index for index, vertex in enumerate(vertices)}
    graph.sort_neighbors(vertex_order)
    return graph


def format_adjacency(graph):
    lines = []

    for vertex in V:
        neighbors = ", ".join(
            f"{neighbor}(cost={cost})"
            for neighbor, cost in graph.adjacency[vertex]
        )
        lines.append(f"{vertex}: {neighbors}")

    return "\n".join(lines)


def main():
    graph = build_graph(V, E, H)

    print("Tap dinh V:")
    print(V)
    print()
    print("Heuristic H:")
    print(H)
    print()
    print("Tap canh E:")
    print(E)
    print()
    print("Danh sach ke:")
    print(format_adjacency(graph))


if __name__ == "__main__":
    main()
# Out:
# Tap dinh V:
# ['S', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'K', 'M', 'N', 'I', 'J', 'L', 'Z']
#
# Heuristic H:
# {'S': 10, 'A': 9, 'B': 8, 'C': 7, 'D': 6, 'E': 5, 'F': 4, 'G': 10, 'H': 10, 'K': 3, 'M': 0, 'N': 10, 'I': 6, 'J': 0, 'L': 9, 'Z': 8}
#
# Tap canh E:
# [('S', 'A', 5), ('S', 'B', 6), ('S', 'C', 5), ('A', 'D', 6), ('A', 'E', 7), ('D', 'M', 5), ('D', 'N', 8), ('E', 'I', 8), ('B', 'F', 3), ('B', 'G', 4), ('F', 'J', 4), ('F', 'L', 4), ('C', 'H', 6), ('C', 'K', 4), ('K', 'Z', 2)]
#
# Danh sach ke:
# S: A(cost=5), B(cost=6), C(cost=5)
# A: S(cost=5), D(cost=6), E(cost=7)
# B: S(cost=6), F(cost=3), G(cost=4)
# C: S(cost=5), H(cost=6), K(cost=4)
# D: A(cost=6), M(cost=5), N(cost=8)
# E: A(cost=7), I(cost=8)
# F: B(cost=3), J(cost=4), L(cost=4)
# G: B(cost=4)
# H: C(cost=6)
# K: C(cost=4), Z(cost=2)
# M: D(cost=5)
# N: D(cost=8)
# I: E(cost=8)
# J: F(cost=4)
# L: F(cost=4)
# Z: K(cost=2)

# %% [markdown]
# ### Giải thích câu a
#
# Ở câu a, em biểu diễn cây bằng ba thành phần chính:
#
# - `V` là danh sách toàn bộ các đỉnh trong cây.
# - `H` là bảng trọng số heuristic trên đỉnh. Đỉnh đích là đỉnh có `h = 0`, trong bài này gồm `M` và `J`.
# - `E` là danh sách cạnh, mỗi cạnh có dạng `(đỉnh_1, đỉnh_2, chi_phí)`.
#
# Vì cây trong bài được xem là vô hướng nên khi thêm cạnh, chương trình thêm cả hai chiều vào danh sách kề. Ví dụ cạnh `("S", "A", 5)` cho biết có thể đi từ `S` sang `A` và từ `A` về `S`, với chi phí cạnh bằng `5`.
#
# Class `Graph` lưu hai thông tin quan trọng:
#
# - `adjacency` lưu danh sách kề của từng đỉnh, kèm chi phí cạnh.
# - `heuristic` lưu giá trị `h(n)` của từng đỉnh.
#
# Sau khi khởi tạo xong cây, chương trình in ra tập đỉnh, bảng heuristic, tập cạnh và danh sách kề để kiểm tra dữ liệu đã đúng với đề bài.

# %% [markdown]
# b)	Hãy viết chương trình sử dụng thuật toán BFS để tìm đường đi từ đỉnh `S` đến tất cả các đỉnh có `h = 0`. Trong chương trình, hãy in ra thứ tự đỉnh khám phá trong quá trình tìm kiếm và bảng trạng thái hàng đợi.

# %% [markdown]
# Dán code:

# %%
from collections import deque


V = ["S", "A", "B", "C", "D", "E", "F", "G", "H", "K", "M", "N", "I", "J", "L", "Z"]

H = {
    "S": 10,
    "A": 9,
    "B": 8,
    "C": 7,
    "D": 6,
    "E": 5,
    "F": 4,
    "G": 10,
    "H": 10,
    "K": 3,
    "M": 0,
    "N": 10,
    "I": 6,
    "J": 0,
    "L": 9,
    "Z": 8,
}

E = [
    ("S", "A", 5),
    ("S", "B", 6),
    ("S", "C", 5),
    ("A", "D", 6),
    ("A", "E", 7),
    ("D", "M", 5),
    ("D", "N", 8),
    ("E", "I", 8),
    ("B", "F", 3),
    ("B", "G", 4),
    ("F", "J", 4),
    ("F", "L", 4),
    ("C", "H", 6),
    ("C", "K", 4),
    ("K", "Z", 2),
]


class Graph:
    def __init__(self):
        self.adjacency = {}
        self.heuristic = {}

    def add_node(self, node, heuristic_value):
        if node not in self.adjacency:
            self.adjacency[node] = []
        self.heuristic[node] = heuristic_value

    def add_edge(self, u, v, cost):
        self.adjacency[u].append((v, cost))
        self.adjacency[v].append((u, cost))

    def sort_neighbors(self, vertex_order):
        for node in self.adjacency:
            self.adjacency[node].sort(key=lambda item: vertex_order[item[0]])


def build_graph(vertices, edges, heuristic_values):
    graph = Graph()
    for vertex in vertices:
        graph.add_node(vertex, heuristic_values[vertex])
    for u, v, cost in edges:
        graph.add_edge(u, v, cost)
    vertex_order = {vertex: index for index, vertex in enumerate(vertices)}
    graph.sort_neighbors(vertex_order)
    return graph


def reconstruct_path(parent, start, goal):
    path = []
    current = goal
    while current is not None:
        path.append(current)
        current = parent[current]
    path.reverse()
    return path if path[0] == start else None


def path_cost(path, graph):
    total = 0
    for u, v in zip(path, path[1:]):
        for neighbor, cost in graph.adjacency[u]:
            if neighbor == v:
                total += cost
                break
    return total


def bfs_to_zero_heuristic_goals(graph, start):
    queue = deque([start])
    visited = {start}
    parent = {start: None}
    exploration_order = []
    steps = []
    goals = []

    while queue:
        queue_before = list(queue)
        current = queue.popleft()
        exploration_order.append(current)

        if graph.heuristic[current] == 0:
            path = reconstruct_path(parent, start, current)
            goals.append({
                "goal": current,
                "path": path,
                "cost": path_cost(path, graph),
            })
            steps.append({
                "queue_before": queue_before,
                "current": current,
                "h": graph.heuristic[current],
                "added": [],
                "queue_after": list(queue),
                "note": "Ghi nhan dinh dich h = 0",
            })
            continue

        added = []
        for neighbor, _ in graph.adjacency[current]:
            if neighbor not in visited:
                visited.add(neighbor)
                parent[neighbor] = current
                queue.append(neighbor)
                added.append(neighbor)

        steps.append({
            "queue_before": queue_before,
            "current": current,
            "h": graph.heuristic[current],
            "added": added,
            "queue_after": list(queue),
            "note": "",
        })

    return goals, exploration_order, steps


def format_list(values):
    return "[" + ", ".join(values) + "]"


def make_table(headers, rows):
    widths = [
        max(len(str(row[index])) for row in [headers] + rows)
        for index in range(len(headers))
    ]
    separator = "+" + "+".join("-" * (width + 2) for width in widths) + "+"

    def format_row(row):
        cells = [
            str(value).ljust(widths[index])
            for index, value in enumerate(row)
        ]
        return "| " + " | ".join(cells) + " |"

    lines = [separator, format_row(headers), separator]
    lines.extend(format_row(row) for row in rows)
    lines.append(separator)
    return "\n".join(lines)


def format_steps(steps):
    headers = ["Buoc", "Queue truoc", "Lay ra", "Them vao", "Queue sau"]
    rows = []

    for index, step in enumerate(steps, start=1):
        added = ", ".join(step["added"]) if step["added"] else "Khong co"
        rows.append([
            index,
            format_list(step["queue_before"]),
            f"{step['current']}(h={step['h']})",
            added,
            format_list(step["queue_after"]),
        ])

    return "\n".join([
        "Bang trang thai:",
        make_table(headers, rows),
        "Ghi nhan moi dinh co h = 0 va tiep tuc cho den khi queue rong.",
    ])


def solve():
    graph = build_graph(V, E, H)
    goals, exploration_order, steps = bfs_to_zero_heuristic_goals(graph, "S")
    lines = [
        "THUAT TOAN BFS",
        "Thu tu dinh kham pha:",
        " -> ".join(exploration_order),
        "",
        format_steps(steps),
        "",
    ]
    if not goals:
        lines.append("Khong tim thay duong di")
    else:
        lines.append("Cac dinh dich tim duoc:")
        lines.append(", ".join(item["goal"] for item in goals))
        lines.append("Cac duong di tu S den cac dinh co h = 0:")
        for item in goals:
            lines.append(f'{item["goal"]}: { " -> ".join(item["path"]) } | Tong chi phi = {item["cost"]}')
    return "\n".join(lines)


print(solve())

# %% [markdown]
# ### Giải thích tác dụng của từng hàm
#
# - `Graph.__init__()`: khởi tạo cây rỗng, gồm `adjacency` để lưu danh sách kề và `heuristic` để lưu giá trị `h(n)` của từng đỉnh.
# - `Graph.add_node(node, heuristic_value)`: thêm một đỉnh vào cây và lưu giá trị heuristic của đỉnh đó. Nếu đỉnh chưa có trong danh sách kề thì tạo danh sách kề rỗng cho đỉnh.
# - `Graph.add_edge(u, v, cost)`: thêm cạnh có chi phí giữa hai đỉnh `u` và `v`. Vì cây được biểu diễn dạng vô hướng nên cạnh được lưu ở cả hai chiều.
# - `Graph.sort_neighbors(vertex_order)`: sắp xếp các đỉnh kề theo thứ tự xuất hiện trong tập đỉnh `V`, giúp thứ tự duyệt ổn định và dễ kiểm tra.
# - `build_graph(vertices, edges, heuristic_values)`: tạo đối tượng `Graph`, thêm toàn bộ đỉnh, thêm toàn bộ cạnh, sắp xếp danh sách kề rồi trả về cây hoàn chỉnh.
# - `reconstruct_path(parent, start, goal)`: truy vết đường đi từ đỉnh đích về đỉnh bắt đầu dựa trên dictionary `parent`, sau đó đảo ngược để lấy đường đi đúng chiều từ `start` đến `goal`.
# - `path_cost(path, graph)`: tính tổng chi phí của một đường đi bằng cách cộng chi phí các cạnh liên tiếp trong `path`.
# - `format_list(values)`: chuyển một danh sách giá trị thành chuỗi để in ra màn hình theo định dạng dễ đọc.
# - `make_table(headers, rows)`: tạo bảng văn bản từ tiêu đề cột và các dòng dữ liệu.
# - `format_row(row)`: hàm phụ dùng khi tạo bảng, giúp căn chỉnh dữ liệu của từng dòng.
# - `format_steps(steps)`: chuyển danh sách các bước chạy thuật toán thành bảng trạng thái để người đọc theo dõi quá trình duyệt.
# - `bfs_to_zero_heuristic_goals(graph, start)`: thực hiện BFS từ `start` để tìm tất cả các đỉnh có `h = 0`. Hàm dùng hàng đợi FIFO, duyệt theo từng mức, lưu thứ tự khám phá, lưu cha của mỗi đỉnh và tiếp tục chạy cho đến khi hàng đợi rỗng.
# - `solve()`: xây dựng cây, chạy BFS, gom dữ liệu đầu vào, bảng bước chạy, thứ tự khám phá và kết quả tìm được thành chuỗi kết quả hoàn chỉnh.

# %% [markdown]
# ### Giải thích câu b
#
# Ở câu b, em sử dụng thuật toán BFS để tìm đường đi từ `S` đến tất cả các đỉnh có heuristic bằng `0`.
#
# BFS dùng hàng đợi `queue` để duyệt cây theo từng tầng. Từ `S`, thuật toán xét các đỉnh ở mức gần `S` trước, sau đó mới xét các đỉnh ở mức sâu hơn.
#
# ### Công thức / nguyên tắc sử dụng
#
# BFS không dùng công thức heuristic để chọn đỉnh tiếp theo. Thuật toán chỉ dùng hàng đợi theo nguyên tắc:
#
# ```text
# FIFO = First In, First Out
# ```
#
# Với cây không xét trọng số cạnh trong lúc chọn đỉnh, khi đi từ đỉnh `u` sang đỉnh con hoặc đỉnh kề chưa thăm `v`, mức duyệt có thể hiểu là:
#
# ```text
# level(v) = level(u) + 1
# ```
#
# Điều kiện ghi nhận đích của bài này là:
#
# ```text
# h(current) = 0
# ```
#
# Nghĩa là khi BFS lấy ra một đỉnh có trọng số heuristic bằng `0`, thuật toán lưu lại đỉnh đó là đỉnh đích, truy vết đường đi bằng `parent`, rồi tiếp tục duyệt cho đến khi `queue` rỗng.
#
# Các biến chính trong chương trình:
#
# - `queue` là hàng đợi các đỉnh chờ khám phá.
# - `visited` là tập các đỉnh đã được phát hiện.
# - `parent` lưu cha của mỗi đỉnh để truy vết lại đường đi.
# - `goals` lưu toàn bộ các đỉnh có `h = 0` tìm được.
# - `exploration_order` lưu thứ tự các đỉnh được lấy ra khỏi hàng đợi.
# - `steps` lưu trạng thái hàng đợi trước và sau mỗi bước để lập bảng chạy chi tiết.
#
# BFS không xét trọng số cạnh khi quyết định đỉnh tiếp theo. Chi phí đường đi chỉ được tính sau khi đã truy vết được đường đi đến từng đỉnh đích.

# %% [markdown]
# ### Nhận xét về kết quả câu b
#
# Thứ tự đỉnh khám phá của BFS là:
#
# ```text
# S -> A -> B -> C -> D -> E -> F -> G -> H -> K -> M -> N -> I -> J -> L -> Z
# ```
#
# BFS ghi nhận `M` trước vì `M` được đưa vào hàng đợi trước `J`. Sau đó thuật toán vẫn tiếp tục duyệt phần còn lại của hàng đợi nên tìm thêm được `J`.
#
# Các đỉnh đích có `h = 0` tìm được là:
#
# ```text
# M, J
# ```
#
# Các đường đi tương ứng:
#
# ```text
# M: S -> A -> D -> M | Tổng chi phí = 16
# J: S -> B -> F -> J | Tổng chi phí = 13
# ```

# %% [markdown]
# Dán kết quả thực thi:
#
# ```text
# THUAT TOAN BFS
# Thu tu dinh kham pha:
# S -> A -> B -> C -> D -> E -> F -> G -> H -> K -> M -> N -> I -> J -> L -> Z
#
# Bang trang thai:
# +------+--------------------------+---------+----------+--------------------------+
# | Buoc | Queue truoc              | Lay ra  | Them vao | Queue sau                |
# +------+--------------------------+---------+----------+--------------------------+
# | 1    | [S]                      | S(h=10) | A, B, C  | [A, B, C]                |
# | 2    | [A, B, C]                | A(h=9)  | D, E     | [B, C, D, E]             |
# | 3    | [B, C, D, E]             | B(h=8)  | F, G     | [C, D, E, F, G]          |
# | 4    | [C, D, E, F, G]          | C(h=7)  | H, K     | [D, E, F, G, H, K]       |
# | 5    | [D, E, F, G, H, K]       | D(h=6)  | M, N     | [E, F, G, H, K, M, N]    |
# | 6    | [E, F, G, H, K, M, N]    | E(h=5)  | I        | [F, G, H, K, M, N, I]    |
# | 7    | [F, G, H, K, M, N, I]    | F(h=4)  | J, L     | [G, H, K, M, N, I, J, L] |
# | 8    | [G, H, K, M, N, I, J, L] | G(h=10) | Khong co | [H, K, M, N, I, J, L]    |
# | 9    | [H, K, M, N, I, J, L]    | H(h=10) | Khong co | [K, M, N, I, J, L]       |
# | 10   | [K, M, N, I, J, L]       | K(h=3)  | Z        | [M, N, I, J, L, Z]       |
# | 11   | [M, N, I, J, L, Z]       | M(h=0)  | Khong co | [N, I, J, L, Z]          |
# | 12   | [N, I, J, L, Z]          | N(h=10) | Khong co | [I, J, L, Z]             |
# | 13   | [I, J, L, Z]             | I(h=6)  | Khong co | [J, L, Z]                |
# | 14   | [J, L, Z]                | J(h=0)  | Khong co | [L, Z]                   |
# | 15   | [L, Z]                   | L(h=9)  | Khong co | [Z]                      |
# | 16   | [Z]                      | Z(h=8)  | Khong co | []                       |
# +------+--------------------------+---------+----------+--------------------------+
# Ghi nhan moi dinh co h = 0 va tiep tuc cho den khi queue rong.
#
# Cac dinh dich tim duoc:
# M, J
# Cac duong di tu S den cac dinh co h = 0:
# M: S -> A -> D -> M | Tong chi phi = 16
# J: S -> B -> F -> J | Tong chi phi = 13
# ```
